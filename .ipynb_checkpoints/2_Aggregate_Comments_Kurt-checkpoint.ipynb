# %%
import os
import sys
import time
from datetime import date
from datetime import datetime
import time
import json
import platform

import stoneburner
#//*** Custom Functions:
#//*** mr_clean_text(input_series)
#//*** tokenize_series(input_series)
#//*** remove_stop_words(input_series)

# //*** Imports and Load Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#//*** Use the whole window in the IPYNB editor
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
#subreddits = ["wallstreetbets", "stocks", "wallstreetbetsOGs", "spacs", "investing", "pennystocks", "stockmarket", "options", "robinhoodpennystocks", "wallstreetbetsnew", "smallstreetbets"]
filepath = "./data/"
#filename_suffix = "_comments.csv.zip"
#//*** Maximize columns and rows displayed by pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#//*** Path to file aggregate
input_filename = "./data/processed_reddit_v4_1min.csv.zip"

input_filename = "./data/processed_reddit_v4_1min_test.pkl"
input_filename = "./ignore_folder/processed_reddit_v4_amc_1min_csv.zip"
input_filename = "./ignore_folder/processed_reddit_v4_60min.pkl.zip"
raw_df = pd.read_pickle(input_filename)


raw_df
# Out:
#                     time       open       high        low      close  \
# 0    2019-07-29 08:00:00  10.770750  10.866067  10.770750  10.866067
# 1    2019-07-29 09:00:00  10.675434  10.923256  10.675434  10.723092
# 2    2019-07-29 10:00:00  10.913725  10.923256  10.418080  10.429136
# 3    2019-07-29 11:00:00  10.422845  10.713560  10.418080  10.694497
# 4    2019-07-29 12:00:00  10.694497  10.713560  10.580117  10.646839
# ...                  ...        ...        ...        ...        ...
# 6863 2021-07-15 15:00:00  33.938900  35.430000  33.330000  35.329100
# 6864 2021-07-15 16:00:00  35.330000  36.100000  34.670000  35.991100
# 6865 2021-07-15 17:00:00  35.960000  39.200000  35.760000  39.170000
# 6866 2021-07-15 18:00:00  39.170000  39.870000  38.250000  38.750000
# 6867 2021-07-15 19:00:00  38.750000  38.850000  38.000000  38.290000
#
#         volume                                               body  \
# 0         2492  Was my favorite HMD until INDX came out. short...
# 1         2200
# 2       564758
# 3       247215
# 4       284815
# ...        ...                                                ...
# 6863  16629161
# 6864  19774603
# 6865   4218169
# 6866   3911023
# 6867    923939
#
#       comment_count
# 0                40
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 6863              0
# 6864              0
# 6865              0
# 6866              0
# 6867              0
#
# [6868 rows x 8 columns]

# %%
#//*** Already combined
"""
#//************************************************
#//*** Combine Body Text for each Stock Time
#//************************************************
tdf = pd.DataFrame()

print(len(raw_df['time'].unique()))
print("Starting Body Aggregation....")
start_time = time.time()
for group in raw_df.groupby('time'):
    
    #//*** Build aa temporary Series by grabbing the first line of the group[1] dataframe
    #//*** Only Body will update, the rest are static
    loop_series = group[1].iloc[0].copy()

    
    #//*** Combine all body strings into a single string, add to loop_series['body']
    loop_series['body'] = " ".join(list(group[1]['body']))
    #//*** Build a dataframe to hold the Series.
    #//*** Add Dataframe to tdf
    #print(loop_series)
    tdf = pd.concat ([tdf,pd.DataFrame(data=[loop_series], columns = list(group[1].columns))])

print(f"Built: {round(time.time()-start_time,2)}")
tdf
"""
print()

# %%
#//************************************************
#//*** Clean text body
#//************************************************

raw_df['token'] = stoneburner.remove_stop_words(stoneburner.tokenize_series(stoneburner.mr_clean_text(raw_df['body'],{"remove_empty":False})))
print("Done")

#//*** Detokenize the clean column as tfidf
raw_df['tfidf'] = raw_df['token'].apply(lambda x: ' '.join(x))
# Out:
# remove_empty False
# Text Cleaning Time: 34.12254476547241
# Tokenize Time: 28.13885498046875
# Stop Words Time: 20.742707014083862
# Done

# %%
#//*** Build tfidf
from sklearn.feature_extraction.text import TfidfVectorizer

#loop_list.append(tfidf.fit_transform(input_df['tfidf']))
tfidf_matrix = []
tfidf_list = []
tfidf = TfidfVectorizer()

print("Starting tfidf....")
start_time = time.time()
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(raw_df['tfidf'])


print(f"Built: {round(time.time()-start_time,2)}")

print(tfidf_matrix)
print
# Out:
# Starting tfidf....
# Built: 4.67
#   (0, 14299)	0.03401961698924732
#   (0, 74899)	0.04682019536046372
#   (0, 81673)	0.030586264755460793
#   (0, 48755)	0.015477205176876974
#   (0, 54192)	0.02696689468332636
#   (0, 109155)	0.024218678637912047
#   (0, 95210)	0.017444858699409642
#   (0, 56220)	0.027932558423931587
#   (0, 105071)	0.09848800926392938
#   (0, 60648)	0.06003137748849249
#   (0, 65489)	0.02038803993539359
#   (0, 112084)	0.05847955838699228
#   (0, 107166)	0.03393851063884545
#   (0, 76114)	0.030566550978695962
#   (0, 58136)	0.02280262763934598
#   (0, 101644)	0.013389877265936084
#   (0, 36280)	0.027598467281734373
#   (0, 75327)	0.029691281040632955
#   (0, 90284)	0.06621325995138741
#   (0, 54337)	0.020742196951851536
#   (0, 20812)	0.03866277717354503
#   (0, 104988)	0.07752359839186433
#   (0, 61244)	0.025487585687380587
#   (0, 76213)	0.02946300083732014
#   (0, 79548)	0.03671942130676892
#   :	:
#   (6706, 79279)	0.03725580570711172
#   (6706, 101607)	0.04767484929925102
#   (6706, 97594)	0.03956442029169066
#   (6706, 71133)	0.04403465577675771
#   (6706, 38048)	0.04001365958043071
#   (6706, 17680)	0.03779048771594132
#   (6706, 93008)	0.050584646193643855
#   (6706, 113453)	0.03140550701780037
#   (6706, 91595)	0.036832005086660374
#   (6706, 35715)	0.0838933392035929
#   (6706, 70926)	0.05128443690209715
#   (6706, 88427)	0.07596544474809516
#   (6706, 72071)	0.03693312738369851
#   (6706, 109608)	0.054222483284428566
#   (6706, 68525)	0.050455954492025654
#   (6706, 65122)	0.06552238199382009
#   (6706, 67263)	0.0560464058000737
#   (6706, 31482)	0.08724631409179065
#   (6706, 103122)	0.06713076094100864
#   (6706, 41012)	0.0780029231753176
#   (6706, 101180)	0.06034952214308147
#   (6706, 97121)	0.06782595872214708
#   (6706, 112099)	0.034535436221026325
#   (6706, 103188)	0.06745075757660655
#   (6706, 97469)	0.03454576100877318
# <function print>

# %%
tfidf.get_feature_names()
# Out:
# ['00',
#  '000',
#  '0000',
#  '00000',
#  '000000',
#  '00000000000000000000000000000001',
#  '00000000001',
#  '0000000001',
#  '000000001bn',
#  '000000014',
#  '0000001',
#  '0000002',
#  '0000005',
#  '000001',
#  '0000083',
#  '00001',
#  '000010101',
#  '000012',
#  '00002',
#  '00002400',
#  '000042069',
#  '00007012020outstanding',
#  '00009',
#  '0001',
#  '000130',
#  '0001353487',
#  '0001434647there',
#  '00015',
#  '000160',
#  '0002',
#  '000200',
#  '00024',
#  '00025',
#  '0003',
#  '00030',
#  '000324',
#  '000333',
#  '0004',
#  '0005',
#  '00055',
#  '000552017',
#  '0005share',
#  '0006',
#  '00060008',
#  '000600zhttpswww',
#  '000600zutmname',
#  '00063',
#  '00063httpsonlinelibrary',
#  '0007',
#  '0007500',
#  '0008',
#  '000816',
#  '0009',
#  '00095383bitfinex3abtcusd292fbitfinex3abtcusd2a100this',
#  '000and',
#  '000cap',
#  '000considering',
#  '000crpt',
#  '000date',
#  '000eat',
#  '000er',
#  '000eur',
#  '000going',
#  '000good',
#  '000he',
#  '000hello',
#  '000hopefully',
#  '000httpsi',
#  '000httpswww',
#  '000httpwww',
#  '000i',
#  '000im',
#  '000in',
#  '000investing',
#  '000ish',
#  '000jan',
#  '000k',
#  '000minimum',
#  '000month',
#  '000now',
#  '000outstanding',
#  '000put',
#  '000s',
#  '000sell',
#  '000shares',
#  '000singcell',
#  '000so',
#  '000th',
#  '000thats',
#  '000the',
#  '000theres',
#  '000too',
#  '000total',
#  '000trade',
#  '000turtletree',
#  '000us',
#  '000usd',
#  '000volume',
#  '000vryyf',
#  '000win',
#  '000x',
#  '000x23',
#  '000year',
#  '000yearinitial',
#  '000yes',
#  '000you',
#  '000yr',
#  '001',
#  '0010',
#  '00100',
#  '001001zhttpswww',
#  '001001zmessage',
#  '00100k250k',
#  '001040',
#  '0011',
#  '0012',
#  '0013',
#  '00137',
#  '0014',
#  '0015',
#  '00150',
#  '001534',
#  '0016',
#  '0017',
#  '0018',
#  '0019',
#  '00199',
#  '001b000000nmi1qaat',
#  '001b000000nmi1qaathttpsregister',
#  '001s',
#  '002',
#  '0020',
#  '0020s',
#  '0022',
#  '0023',
#  '002391',
#  '0024',
#  '002400',
#  '0025',
#  '00259started',
#  '0026',
#  '0027',
#  '00278',
#  '0028',
#  '0029',
#  '00293',
#  '002ish',
#  '002key',
#  '002nothing',
#  '003',
#  '0030',
#  '0030s',
#  '0031',
#  '00312',
#  '00318',
#  '0032',
#  '0033',
#  '0034',
#  '0035',
#  '0036',
#  '00361',
#  '0038',
#  '0038863',
#  '003a003a00',
#  '003a003a00heres',
#  '003a003a00this',
#  '003getting',
#  '003pps',
#  '003t',
#  '004',
#  '0040',
#  '00406',
#  '0041',
#  '0042',
#  '0044',
#  '004435511',
#  '0045',
#  '0047',
#  '00475',
#  '0048',
#  '004thats',
#  '005',
#  '00500088',
#  '0051',
#  '0053',
#  '0054',
#  '0055',
#  '0056',
#  '0058',
#  '005c',
#  '006',
#  '0061',
#  '0065',
#  '0067',
#  '006s',
#  '007',
#  '0074',
#  '0075',
#  '007559',
#  '007and',
#  '008',
#  '0081',
#  '00847',
#  '0085',
#  '0086',
#  '008750k',
#  '0088',
#  '0088btc',
#  '0089',
#  '0089wish',
#  '009',
#  '0090',
#  '0094',
#  '0095',
#  '0097',
#  '00a',
#  '00ask',
#  '00at',
#  '00b',
#  '00but',
#  '00buy',
#  '00c',
#  '00clientmonth',
#  '00contract',
#  '00current',
#  '00delta',
#  '00edit',
#  '00feb',
#  '00gallon',
#  '00hope',
#  '00httpopcalc',
#  '00i',
#  '00if',
#  '00iv',
#  '00lets',
#  '00march',
#  '00max',
#  '00month',
#  '00net',
#  '00neutral',
#  '00ounce',
#  '00out',
#  '00p',
#  '00pls',
#  '00pm',
#  '00s',
#  '00sell',
#  '00share',
#  '00spy',
#  '00srne',
#  '00still',
#  '00the',
#  '00they',
#  '00this',
#  '00todays',
#  '00we',
#  '00x100',
#  '00year',
#  '00you',
#  '01',
#  '010',
#  '0100',
#  '01012000',
#  '01012021',
#  '0102',
#  '0103',
#  '010328',
#  '0104probably',
#  '0107',
#  '010746',
#  '0108',
#  '0109',
#  '010portfolio',
#  '011',
#  '01100',
#  '011000its',
#  '011127',
#  '0112',
#  '0113',
#  '011420',
#  '0115',
#  '01152021',
#  '011521',
#  '0115212',
#  '0116',
#  '0117',
#  '011753',
#  '011809',
#  '011823',
#  '011844zelperro07thanks',
#  '011844zhttpswww',
#  '012',
#  '012020',
#  '01202023',
#  '012021',
#  '012022',
#  '012023',
#  '0121',
#  '012122',
#  '0122',
#  '012222',
#  '0124',
#  '0125',
#  '0126',
#  '0128',
#  '0129',
#  '013',
#  '0132',
#  '0135',
#  '0136',
#  '013605',
#  '0137',
#  '0139',
#  '014',
#  '0142',
#  '0144',
#  '0147',
#  '0148',
#  '015',
#  '0150',
#  '0152',
#  '0153',
#  '016',
#  '0160rsi',
#  '0161',
#  '0165',
#  '0168',
#  '017',
#  '0170',
#  '0176',
#  '017patience',
#  '017planning',
#  '018',
#  '0182',
#  '0188',
#  '0189',
#  '019',
#  '0194',
#  '01984',
#  '01c',
#  '01close',
#  '01entry',
#  '01er',
#  '01gogogogogo',
#  '01innovative',
#  '01m53',
#  '01not',
#  '01other',
#  '01q9r7dahi',
#  '01q9r7dahihttpsyoutube',
#  '01s',
#  '01share',
#  '01so',
#  '01trnx',
#  '01value',
#  '01wfc',
#  '02',
#  '020',
#  '020221',
#  '02032021',
#  '02042021',
#  '020421',
#  '02062018',
#  '0208',
#  '020852zhttpswww',
#  '020852zp',
#  '020today',
#  '021',
#  '02100',
#  '021000021',
#  '0211',
#  '0212',
#  '0214',
#  '02140',
#  '0215',
#  '0217',
#  '02182015',
#  '0219',
#  '021it',
#  '022',
#  '02202020the',
#  '0221',
#  '022520',
#  '0228',
#  '023',
#  '0232',
#  '0233',
#  '0234',
#  '02344',
#  '0236my',
#  '023759',
#  '024',
#  '0241',
#  '024103',
#  '0243',
#  '024519',
#  '0249',
#  '024ea4585d3211e58a5e0015c588e0f6',
#  '025',
#  '0250',
#  '02500',
#  '0252',
#  '025bps',
#  '026',
#  '0265',
#  '027',
#  '0275',
#  '0276',
#  '0277',
#  '028',
#  '0285',
#  '0287',
#  '028and',
#  '028s',
#  '029',
#  '0297',
#  '02day',
#  '02m',
#  '02qqq',
#  '02v',
#  '02whirlpool',
#  '02would',
#  '03',
#  '030',
#  '0300',
#  '030005',
#  '03012017',
#  '0303',
#  '0306',
#  '03061',
#  '030620',
#  '03091',
#  '030s',
#  '031',
#  '0313',
#  '03132020',
#  '0315',
#  '031620',
#  '0318',
#  '0319',
#  '032',
#  '0320',
#  '03202020',
#  '032136',
#  '032347',
#  '0325',
#  '03252019',
#  '0326',
#  '0327',
#  '033',
#  '0330',
#  '0331you',
#  '0332013',
#  '03384',
#  '034',
#  '0341',
#  '0342008',
#  '03425',
#  '035',
#  '0355',
#  '035827',
#  '035fspfx',
#  '035percent',
#  '036',
#  '0365',
#  '037',
#  '0375',
#  '038',
#  '038cents',
#  '039',
#  '0391',
#  '0393',
#  '03b',
#  '03c',
#  '03cad',
#  '03current',
#  '03edit',
#  '03fzilx',
#  '03i',
#  '03jan',
#  '03m',
#  '03s',
#  '03share',
#  '03thanks',
#  '04',
#  '040',
#  '0400',
#  '0401',
#  '04012021',
#  '0403',
#  '0406',
#  '0408',
#  '041',
#  '04152020',
#  '0416',
#  '0417',
#  '041925zhttpswww',
#  '041925zthat',
#  '042',
#  '0420',
#  '042020',
#  '042021',
#  '042228',
#  '042648z',
#  '042648zhttpswww',
#  '0428',
#  '04282020',
#  '042f072f2020',
#  '042f222f2020',
#  '043',
#  '043020',
#  '043830',
#  '044',
#  '0445',
#  '045',
#  '0454',
#  '045shr',
#  '0463',
#  '0464',
#  '048',
#  '049',
#  '04all',
#  '04b',
#  '04c',
#  '04cm',
#  '04day',
#  '04fsly',
#  '04helplearnoptionsummary',
#  '04httpsmobile',
#  '04ish',
#  '04m',
#  '04s',
#  '04straddles',
#  '04wdc',
#  '04x',
#  '04ye',
#  '04your',
#  '05',
#  '050',
#  '0501',
#  '05052020',
#  '050803',
#  '050usdxbt',
#  '051',
#  '05112021',
#  '05122020',
#  '051420',
#  '0515',
#  '0518',
#  '05182020',
#  '051net',
#  '052',
#  '0522',
#  '0526',
#  '0529',
#  '052f012f2020',
#  '053',
#  '054',
#  '055',
#  '0557',
#  '055fuck',
#  '056',
#  '0560',
#  '057',
#  '059',
#  '05agtc',
#  '05average',
#  '05c',
#  '05closed',
#  '05ideas',
#  '05if',
#  '05ish',
#  '05just',
#  '05pm',
#  '05s',
#  '05share',
#  '05that',
#  '05total',
#  '05vega',
#  '05x100',
#  '05you',
#  '05zasingthe',
#  '06',
#  '060',
#  '0605',
#  '0607',
#  '060714',
#  '061',
#  '0612',
#  '0618',
#  '0619',
#  '062',
#  '0625',
#  '0626',
#  '063',
#  '0630',
#  '065',
#  '066',
#  '067',
#  '0675',
#  '068',
#  '06800',
#  '069',
#  '0694',
#  '06again',
#  '06baba',
#  '06dis',
#  '06fl',
#  '06iv',
#  '06m',
#  '06open',
#  '06share',
#  '06shareedit',
#  '06so',
#  '06the',
#  '06wmt',
#  '06x',
#  '07',
#  '070120',
#  '0702',
#  '07032',
#  '0708',
#  '0709',
#  '071',
#  '07132025',
#  '0714',
#  '0716',
#  '0717',
#  '071720',
#  '071vanguard',
#  '072',
#  '0720',
#  '072httpsi',
#  '0731',
#  '0737',
#  '073765',
#  '0747',
#  '0749',
#  '075',
#  '076',
#  '0765',
#  '077',
#  '079',
#  '0794',
#  '0798',
#  '07avg',
#  '07churchillmultiplanpublicannouncementpresentation',
#  '07hold',
#  '07ish',
#  '07msft',
#  '07time',
#  '07usd',
#  '07wlect18',
#  '07x',
#  '08',
#  '080320',
#  '0807',
#  '0809',
#  '080share',
#  '0811',
#  '0812',
#  '08142020',
#  '08162020',
#  '082',
#  '0820',
#  '0821',
#  '0821i',
#  '0828',
#  '082cancer',
#  '083',
#  '0830',
#  '0834',
#  '0834does',
#  '0837',
#  '083nd1nd1',
#  '083you',
#  '084',
#  '085',
#  '0850',
#  '086',
#  '088',
#  '089',
#  '08943',
#  '0899',
#  '08c',
#  '08dog',
#  '08g',
#  '08ill',
#  '08ish',
#  '08k',
#  '08overline30',
#  '08share',
#  '08sld',
#  '08this',
#  '08x100',
#  '09',
#  '090',
#  '0900',
#  '090000z',
#  '090000zhttpswww',
#  '0901',
#  '090320',
#  '091',
#  '0910',
#  '09152020',
#  '0916',
#  '0918',
#  '09182020',
#  '0918buy',
#  '092',
#  '0920',
#  '0921',
#  '0925',
#  '0930',
#  '09301130',
#  '093020',
#  '09311538bitfinex3aethusd292fbitfinex3aethusd2a100',
#  '0946',
#  '0948',
#  '0949',
#  '095',
#  '0977',
#  '098',
#  '099',
#  '09and',
#  '09c',
#  '09having',
#  '09httpstwitter',
#  '09i',
#  '09m',
#  '09s',
#  '09started',
#  '0a',
#  '0apr',
#  '0at',
#  '0beyond',
#  '0btc',
#  '0but',
#  '0c',
#  '0cainn4rsi8',
#  '0counterfeitingstock',
#  '0ct',
#  '0d',
#  '0day',
#  '0does',
#  '0dont',
#  '0dte',
#  '0dtes',
#  '0dummy',
#  '0ecqdapjjv0',
#  '0ecqdapjjv0httpswww',
#  '0ed',
#  '0etc',
#  '0f',
#  '0feedback',
#  '0feel',
#  '0file2924022958432a1257367accesstoken',
#  '0hadox1',
#  '0httpsdocs',
#  '0i',
#  '0if',
#  '0ish',
#  '0it',
#  '0just',
#  '0k',
#  '0kind',
#  '0l',
#  '0lets',
#  '0mi',
#  '0mm',
#  '0nicer',
#  '0note',
#  '0o',
#  '0p',
#  '0pdeyafgfimill',
#  '0pigs',
#  '0plotbasis',
#  '0portfolio',
#  '0r',
#  '0really',
#  '0realtime',
#  '0resize840x547quality90url',
#  '0revenue',
#  '0roth',
#  '0s',
#  '0share',
#  '0simpler',
#  '0somth',
#  '0sttrsdod3c',
#  '0study',
#  '0tde',
#  '0u',
#  '0unless',
#  '0upside412953667',
#  '0want',
#  '0we',
#  '0which',
#  '0white',
#  '0x',
#  '0x2e4c9cdfac92f3abd020b769ef8e3676ca0e6762',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '100000',
#  '1000000',
#  '100000000',
#  '1000000000',
#  '100000000000',
#  '1000000000000000000000000000000',
#  '1000000x',
#  '100000s',
#  '100000x',
#  '100001010111010100111001011000',
#  '10000having',
#  '10000k',
#  '10000pm',
#  '10000s',
#  '10000x',
#  '10001',
#  '10001400',
#  '10002',
#  '10002000',
#  '10003000',
#  '1000333',
#  '10004',
#  '1000455292040',
#  '1000470159420',
#  '1000491765196skip',
#  '10005',
#  '1000800',
#  '1000aids',
#  '1000am',
#  '1000am1200pm',
#  '1000c',
#  '1000contract',
#  '1000ers',
#  '1000execute',
#  '1000hp',
#  '1000i',
#  '1000if',
#  '1000iq',
#  '1000k',
#  '1000k10000k',
#  '1000kilos',
#  '1000km',
#  '1000lb',
#  '1000mo',
#  '1000month',
#  '1000not',
#  '1000oz',
#  '1000p',
#  '1000painting',
#  '1000pm',
#  '1000ps',
#  '1000pt',
#  '1000pton',
#  '1000s',
#  '1000sh',
#  '1000share',
#  '1000shares',
#  '1000shertz',
#  '1000th',
#  '1000usd',
#  '1000x',
#  '1000x200',
#  '1000yolo',
#  '1000yr',
#  '1001',
#  '10010',
#  '100100',
#  '1001000',
#  '1001000111010110',
#  '100100k',
#  '100101',
#  '100105',
#  '100110',
#  '100112',
#  '100115',
#  '100120',
#  '100125',
#  '100125share',
#  '10013',
#  '100140',
#  '100150',
#  '100150k',
#  '1002',
#  '10020',
#  '100200',
#  '100200k',
#  '10020210415',
#  '100250k',
#  '10028',
#  '1002am',
#  '1002w',
#  '1003',
#  '100300',
#  '100300m',
#  '100300milhttpswww',
#  '1003am',
#  '1004',
#  '100400',
#  '10041',
#  '100450',
#  '1005',
#  '100500',
#  '1006',
#  '10060',
#  '100600',
#  '1007',
#  '1007s4009501602233',
#  '1008',
#  '100807080100',
#  '1009',
#  '10091',
#  '10095',
#  '100already',
#  '100at',
#  '100b',
#  '100barrel',
#  '100bday',
#  '100billion',
#  '100bn',
#  '100btw',
#  '100bucks',
#  '100buy',
#  '100buying',
#  '100c',
#  '100calls',
#  '100camb',
#  '100cm',
#  '100contract',
#  '100cs',
#  '100cto',
#  '100d',
#  '100day',
#  '100dollar',
#  '100dow',
#  '100each',
#  '100edit',
#  '100eur',
#  '100euro',
#  '100f',
#  '100gain',
#  '100games',
#  '100gb',
#  '100httpswww',
#  '100hvbtf',
#  '100if',
#  '100in',
#  '100increase',
#  '100ipoa',
#  '100ish',
#  '100it',
#  '100just',
#  '100k',
#  '100k1m',
#  '100k250k',
#  '100k3',
#  '100k500k',
#  '100k500kits',
#  '100khowever',
#  '100km',
#  '100ks',
#  '100kshare',
#  '100kwh',
#  '100kyear',
#  '100kyr',
#  '100look',
#  '100m',
#  '100ma',
#  '100mg',
#  '100mil',
#  '100mile',
#  '100mill',
#  '100million',
#  '100millions',
#  '100mm',
#  '100mo',
#  '100month',
#  '100monthhowever',
#  '100myear',
#  '100nflx',
#  '100on',
#  '100oz',
#  '100p',
#  '100pbto',
#  '100pfe',
#  '100profit',
#  '100ps',
#  '100pt',
#  '100pts',
#  '100quarter',
#  '100record',
#  '100roi',
#  '100s',
#  '100s1000s',
#  '100sells',
#  '100share',
#  '100shares',
#  ...]

# %%
tfidf_matrix = pd.DataFrame(tfidf_matrix.toarray())

# %%
tfidf_matrix.columns = tfidf.get_feature_names()
matrix_cols = tfidf_matrix.columns
tfidf_matrix.columns
# Out:
# Index(['00', '000', '0000', '00000', '000000',
#        '00000000000000000000000000000001', '00000000001', '0000000001',
#        '000000001bn', '000000014',
#        ...
#        '𝗧𝗵𝗲', '𝗯𝗲', '𝗰𝗮𝗹𝗹𝗲𝗱', '𝗺𝗮𝗿𝗴𝗶𝗻', '𝗺𝗮𝗿𝗸𝗲𝘁𝘀', '𝗺𝗼𝗼𝗻', '𝗺𝗼𝗼𝗻𝘀', '𝘀𝘁𝗼𝗰𝗸𝘀',
#        '𝘁𝗿𝗮𝗱𝗲', '𝘆𝗼𝘂𝗿'],
#       dtype='object', length=114209)

# %%
train_cols = ['time','volume','close']
for x in [1,2,3,4,5,6,12,24,48,36]:
    #print(f1['close'][-x:])
    #f1[f"close_{x}"] = list(f1['close'][x:]) + list(f1['close'][:x].to_numpy())
    #print(len(f1),len(list(f1['close'][x:])),len(list(f1['close'][:x])))
    #print(list(np.empty( len(f1)-x )))
    
    nan_list = list(np.empty( x )* np.nan )

    raw_df[f"close_{x}"] = list(raw_df['close'][x:]) + nan_list 
    train_cols.append(f"close_{x}")
#raw_df.tail(50)

#//*** Add stock data + training data to 
#for col in train_cols:
    
    #tfidf_matrix[col] = raw_df[col]

#list(train_cols + list(matrix_cols))
# Out:
# time
# volume
# close
# close_1
# close_2
# close_3
# close_4
# close_5
# close_6
# close_12
# close_24
# close_48
# close_36

# %%
tfidf_matrix.columns = list(train_cols) + list(matrix_cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-43b8363f0168> in <module>
# ----> 1 tfidf_matrix.columns = list(train_cols) + list(matrix_cols)
#       2
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     175
#     176         if new_len != old_len:
# --> 177             raise ValueError(
#     178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 114219 elements, new values have 114222 elements

# %%
"""
import pickle
output_filename = "./data/processed_reddit_v4_60min_tfidf.pkl"

with open(output_filename, 'wb') as f:
    pickle.dump(tfidf, f)

output_filename = "./ignore_folder/processed_reddit_v4_60min_tfidf_matrix.pkl"
with open(output_filename, 'wb') as f:
    pickle.dump(tfidf_matrix, f)
"""
print()

# %%
"""output_filename = "./data/processed_reddit_v4_1min_amc_stock_comments.csv.zip"

#//*** Cleanup columns for storage
if 'body' in tdf.columns:
    del tdf['body']
    del tdf['tfidf']

tdf.to_csv(output_filename, compression='zip')
"""
print()
